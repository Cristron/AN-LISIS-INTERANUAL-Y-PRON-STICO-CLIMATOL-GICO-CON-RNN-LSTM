# %%
from google.colab import drive
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp "/content/drive/My Drive/BaseDeDatos/ClimateEngineTmin.csv" "/content/"

# %%
Tmin = pd.read_csv("ClimateEngineTmin.csv",sep=';')

# %%
Tmin.columns = [None] * len(Tmin.columns)
Tmin.columns = ['Fecha','Temperatura_Minima']

# %%
Tmin['Fecha'] = pd.to_datetime(Tmin['Fecha'], format='%Y-%m-%d:%I %p')
Tmin['Fecha'] = pd.to_datetime(Tmin['Fecha'])
Tmin.set_index('Fecha', inplace=True)
Tmin = Tmin.asfreq('D')

# %%
Tmin['Temperatura_Minima'] = Tmin['Temperatura_Minima'].str.replace(',', '.')
Tmin['Temperatura_Minima'] = Tmin['Temperatura_Minima'].astype(float)

# %%
Tmin.isnull().sum()
# Out:
# Temperatura_Minima    0
# dtype: int64

# %%
Tmin
# Out:
#             Temperatura_Minima
# Fecha
# 2000-01-01                6.45
# 2000-01-02                6.55
# 2000-01-03                6.65
# 2000-01-04                7.45
# 2000-01-05                6.25
# ...                        ...
# 2022-12-27                6.45
# 2022-12-28                7.55
# 2022-12-29                4.75
# 2022-12-30                3.25
# 2022-12-31                5.65
#
# [8401 rows x 1 columns]

# %%
completo = Tmin.copy()

# %%
completo
# Out:
#             Temperatura_Minima
# Fecha
# 2000-01-01                6.45
# 2000-01-02                6.55
# 2000-01-03                6.65
# 2000-01-04                7.45
# 2000-01-05                6.25
# ...                        ...
# 2022-12-27                6.45
# 2022-12-28                7.55
# 2022-12-29                4.75
# 2022-12-30                3.25
# 2022-12-31                5.65
#
# [8401 rows x 1 columns]

# %%
fechas_a_eliminar = pd.to_datetime(['2011-08-04','2011-08-05','2011-08-06','2011-08-07','2011-08-08','2011-08-09','2011-08-10',
                                    '2011-09-04','2011-10-04','2011-11-04','2012-11-05','2013-11-06','2014-11-07','2015-11-08',
                                    '2022-06-04','2022-07-04','2022-07-14','2022-07-24','2022-07-25'])

# Utilizar loc para establecer el valor de la columna como NaN en las fechas especificadas
imputar = completo.copy()
imputar.loc[fechas_a_eliminar, 'Temperatura_Minima'] = None

# %%
imputar.isnull().sum()
# Out:
# Temperatura_Minima    19
# dtype: int64

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import tensorflow as tf

# %%
# Establecer la semilla para TensorFlow
tf.random.set_seed(123)

imputarTmin = imputar.copy()
# Supongamos que df es tu DataFrame, y 'a_rellenar' es la columna que quieres completar
series = imputarTmin['Temperatura_Minima']

#Eliminar los valores de nan
series_droppednan = series.dropna()

# Crear secuencias de los datos
sequence_length = 15
sequences = []
for i in range(len(series_droppednan) - sequence_length):
    sequences.append(series_droppednan[i:i+sequence_length].values)
sequences = np.array(sequences)

# Ejemplos y etiquetas
X = sequences[:, :-1]
Y = sequences[:, -1]

# Redimensionar los ejemplos para el LSTM
X = np.expand_dims(X, -1)

# Crear el modelo
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(X.shape[1], 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Entrenar el modelo
model.fit(X, Y, epochs=60, verbose=1)

# Utilizar el modelo para introducir valores faltantes
for i in range(len(series)):
    if pd.isnull(series[i]):
        input = np.expand_dims(np.expand_dims(series[i-sequence_length+1:i].values, -1), 0)
        series[i] = model.predict(input)[0, 0]

# Ahora series debería tener los valores faltantes llenados
# Out:
# Epoch 1/60
# 262/262 [==============================] - 7s 22ms/step - loss: 4.0198
# Epoch 2/60
# 262/262 [==============================] - 5s 18ms/step - loss: 2.5094
# Epoch 3/60
# 262/262 [==============================] - 5s 19ms/step - loss: 2.4691
# Epoch 4/60
# 262/262 [==============================] - 5s 20ms/step - loss: 2.4554
# Epoch 5/60
# 262/262 [==============================] - 6s 22ms/step - loss: 2.4690
# Epoch 6/60
# 262/262 [==============================] - 6s 21ms/step - loss: 2.4435
# Epoch 7/60
# 262/262 [==============================] - 5s 18ms/step - loss: 2.4408
# Epoch 8/60
# 262/262 [==============================] - 5s 18ms/step - loss: 2.4374
# Epoch 9/60
# 262/262 [==============================] - 6s 24ms/step - loss: 2.4436
# Epoch 10/60
# 262/262 [==============================] - 5s 21ms/step - loss: 2.4355
# Epoch 11/60
# 262/262 [==============================] - 5s 18ms/step - loss: 2.4407
# Epoch 12/60
# 262/262 [==============================] - 6s 24ms/step - loss: 2.4353
# Epoch 13/60
# 262/262 [==============================] - 6s 22ms/step - loss: 2.4262
# Epoch 14/60
# 262/262 [==============================] - 7s 26ms/step - loss: 2.4293
# Epoch 15/60
# 262/262 [==============================] - 5s 17ms/step - loss: 2.4151
# Epoch 16/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.4443
# Epoch 17/60
# 262/262 [==============================] - 6s 22ms/step - loss: 2.4099
# Epoch 18/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.4149
# Epoch 19/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.4122
# Epoch 20/60
# 262/262 [==============================] - 6s 22ms/step - loss: 2.4272
# Epoch 21/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.3956
# Epoch 22/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.4059
# Epoch 23/60
# 262/262 [==============================] - 6s 23ms/step - loss: 2.3848
# Epoch 24/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.3900
# Epoch 25/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.3881
# Epoch 26/60
# 262/262 [==============================] - 6s 22ms/step - loss: 2.3719
# Epoch 27/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.3674
# Epoch 28/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.3749
# Epoch 29/60
# 262/262 [==============================] - 6s 23ms/step - loss: 2.3517
# Epoch 30/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.3555
# Epoch 31/60
# 262/262 [==============================] - 4s 16ms/step - loss: 2.3442
# Epoch 32/60
# 262/262 [==============================] - 6s 22ms/step - loss: 2.3340
# Epoch 33/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.3284
# Epoch 34/60
# 262/262 [==============================] - 5s 18ms/step - loss: 2.3416
# Epoch 35/60
# 262/262 [==============================] - 6s 23ms/step - loss: 2.3225
# Epoch 36/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.2968
# Epoch 37/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.2876
# Epoch 38/60
# 262/262 [==============================] - 6s 23ms/step - loss: 2.2788
# Epoch 39/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.2664
# Epoch 40/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.2517
# Epoch 41/60
# 262/262 [==============================] - 6s 23ms/step - loss: 2.2256
# Epoch 42/60
# 262/262 [==============================] - 5s 18ms/step - loss: 2.2134
# Epoch 43/60
# 262/262 [==============================] - 6s 25ms/step - loss: 2.1971
# Epoch 44/60
# 262/262 [==============================] - 5s 19ms/step - loss: 2.1752
# Epoch 45/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.1566
# Epoch 46/60
# 262/262 [==============================] - 5s 20ms/step - loss: 2.1298
# Epoch 47/60
# 262/262 [==============================] - 5s 19ms/step - loss: 2.1032
# Epoch 48/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.0865
# Epoch 49/60
# 262/262 [==============================] - 5s 21ms/step - loss: 2.0839
# Epoch 50/60
# 262/262 [==============================] - 5s 19ms/step - loss: 2.0429
# Epoch 51/60
# 262/262 [==============================] - 4s 17ms/step - loss: 2.0072
# Epoch 52/60
# 262/262 [==============================] - 5s 21ms/step - loss: 1.9679
# Epoch 53/60
# 262/262 [==============================] - 5s 18ms/step - loss: 1.9356
# Epoch 54/60
# 262/262 [==============================] - 4s 17ms/step - loss: 1.9135
# Epoch 55/60
# 262/262 [==============================] - 6s 23ms/step - loss: 1.8674
# Epoch 56/60
# 262/262 [==============================] - 5s 18ms/step - loss: 1.8523
# Epoch 57/60
# 262/262 [==============================] - 4s 17ms/step - loss: 1.8193
# Epoch 58/60
# 262/262 [==============================] - 6s 23ms/step - loss: 1.8144
# Epoch 59/60
# 262/262 [==============================] - 5s 18ms/step - loss: 1.7450
# Epoch 60/60
# 262/262 [==============================] - 4s 17ms/step - loss: 1.7038
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
# Crea un nuevo DataFrame con la serie
rnn_imputed = pd.DataFrame({'Temperatura_Minima': series.values}, index=series.index)

# %%
imputar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8401 entries, 2000-01-01 to 2022-12-31
# Freq: D
# Data columns (total 1 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Temperatura_Minima  8382 non-null   float64
# dtypes: float64(1)
# memory usage: 389.3 KB

# %%
linear_imputed = imputar.copy()

# Rellenar valores faltantes utilizando interpolate de pandas
linear_imputed['Temperatura_Minima'] = linear_imputed['Temperatura_Minima'].interpolate(method='linear')

# %%
imputar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8401 entries, 2000-01-01 to 2022-12-31
# Freq: D
# Data columns (total 1 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Temperatura_Minima  8382 non-null   float64
# dtypes: float64(1)
# memory usage: 389.3 KB

# %%
from sklearn.metrics import mean_squared_error

# %%
# Identificar dónde 'imputar' originalmente tenía valores NaN para 'Temperatura_Maxima'
nan_indices = imputar['Temperatura_Minima'].isna()
print(nan_indices)
# Out:
# Fecha
# 2000-01-01    False
# 2000-01-02    False
# 2000-01-03    False
# 2000-01-04    False
# 2000-01-05    False
#               ...
# 2022-12-27    False
# 2022-12-28    False
# 2022-12-29    False
# 2022-12-30    False
# 2022-12-31    False
# Freq: D, Name: Temperatura_Minima, Length: 8401, dtype: bool

# %%
# Asegúrate de que los índices de ambos DataFrame alinean
completo_aligned = completo.loc[nan_indices]
rnn_imputed_aligned = rnn_imputed.loc[nan_indices]
linear_imputed_aligned = linear_imputed.loc[nan_indices]

# %%
# Calcular RMSE para la comparación sólo en los puntos donde habían valores nulos originalmente
rmse_rnn = np.sqrt(mean_squared_error(completo_aligned['Temperatura_Minima'], rnn_imputed_aligned['Temperatura_Minima']))
rmse_linear = np.sqrt(mean_squared_error(completo_aligned['Temperatura_Minima'], linear_imputed_aligned['Temperatura_Minima']))

# %%
print(f'RMSE para la imputación usando RNN: {rmse_rnn}')
print(f'RMSE para la imputación usando regresión lineal: {rmse_linear}')
# Out:
# RMSE para la imputación usando RNN: 1.8213319105573322
# RMSE para la imputación usando regresión lineal: 2.3478309013897207
